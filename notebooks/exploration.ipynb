# %% [markdown]
# # Data Exploration
#
# This notebook explores the FP_MCI dataset with data distributions, correlations, and basic statistics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
# df = pd.read_csv('../data_lake/raw/...')

# %%
# Data overview
# df.head()
# df.describe()
